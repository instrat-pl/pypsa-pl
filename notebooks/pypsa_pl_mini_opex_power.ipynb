# %% [markdown]
# <a href="https://colab.research.google.com/github/instrat-pl/pypsa-pl/blob/main/notebooks/pypsa_pl_mini_opex_power.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PyPSA-PL-mini: OPEX, power system
#
# Simplified energy model for rapid testing and education.
#
# Example of OPEX optimisation for the power system.
#
# Version 1.0
#
# This notebook is released under [CC-BY-4.0](https://creativecommons.org/licenses/by/4.0/) license.
#
# **Contact person:** Patryk Kubiczek (patryk.kubiczek@instrat.pl)

# %% [markdown]
# ## How to use it?
#
# **Start by making your own copy of this notebook (File > Save a copy in Drive).** This notebook, containing an application of the  PyPSA-PL-mini model, is synchronised with the GitHub repository https://github.com/instrat-pl/pypsa-pl. To play with the model, create your own copy of this notebook.
#
# Run the "Configuration" cells which will clone the PyPSA-PL repository into your Google Colab space and which will install all the required libraries. This might take up to a few minutes. After the configuration is finished, you can proceed to experiment with PyPSA-PL-mini. Have fun!

# %% [markdown]
# ## Configuration (run each cell just once)

# %%
import sys
import os

# Optionally install pl_PL.UTF-8 locale in Google Colab
# Source: https://stackoverflow.com/questions/67045349/change-locale-for-google-colab

skip_installing_pl_locale = True

if "google.colab" in sys.modules and not skip_installing_pl_locale:
  # Install pl_PL
  # !/usr/share/locales/install-language-pack pl_PL.UTF-8
  # !dpkg-reconfigure locales
    
  # Restart Python process to pick up the new locales
  os.kill(os.getpid(), 9)

# %%
import sys
import os
from pathlib import Path

instrat_user = False
force_installation = False

if "google.colab" in sys.modules:

  # %cd "/content"

  if instrat_user:  
    
    from google.colab import drive
    root = "/content/drive"
    drive.mount(root)

    def project_dir(*path):
      return Path(root, "MyDrive", "Colab", "PyPSA-PL-mini", *path)

  else:
    
    from google.colab import userdata
    # ghtoken = userdata.get("GHTOKEN")

    # !rm -rf pypsa-pl
    # !git clone https://{ghtoken}@github.com/instrat-pl/pypsa-pl.git
    # !git clone https://github.com/instrat-pl/pypsa-pl.git

    def project_dir(*path):
      return Path("/content", "pypsa-pl", *path)

  # %cd {str(project_dir())}

  if not instrat_user or force_installation:
    # !pip install poetry --quiet
    # !poetry config virtualenvs.in-project false
    # !poetry config virtualenvs.path {str(project_dir("venv"))}
    # !poetry install --no-ansi
    # ipywidgets have to be downgraded in Google Colab
    # !poetry add ipywidgets@7.7.2 --no-ansi
    # Download and install Work Sans font
    # !mkdir fonts
    # %cd fonts  
    # !wget https://github.com/weiweihuanghuang/Work-Sans/raw/master/fonts/ttf/WorkSans-Regular.ttf
    # !wget https://github.com/weiweihuanghuang/Work-Sans/raw/master/fonts/ttf/WorkSans-Medium.ttf
    from matplotlib import font_manager
    font_files = ["WorkSans-Regular.ttf", "WorkSans-Medium.ttf"]
    for font_file in font_files:
        font_manager.fontManager.addfont(font_file)
    # %cd ..

  v = f"{sys.version_info.major}.{sys.version_info.minor}"
  venv_location = !poetry env info -p
  VENV_PATH = os.path.join(venv_location[0], "lib", f"python{v}", "site-packages")
  sys.path.insert(0, VENV_PATH)  
  
  SRC_PATH = str(project_dir("src"))
  sys.path.insert(0, SRC_PATH)

else:
  # %load_ext autoreload
  # %autoreload 2

import pypsa_pl.config

# %% [markdown]
# ## Power system model

# %% [markdown]
# ### Specify parameters

# %%
params = {
    # Run name and year
    "run_name": "pypsa_pl_mini_opex_power",
    "year": 2023,
    # Input data
    "technology_carrier_definitions": "mini",
    "technology_cost_data": "instrat_2024",
    "installed_capacity": "historical_totals",
    "annual_energy_flows": "historical",
    "capacity_utilisation": "historical",
    "capacity_addition_potentials": "instrat_projection", # irrelevant in this example
    "timeseries": "mini",
    # CO2 emissions
    "co2_emissions": None, # no limit on CO2 emissions
    # Weather year
    "weather_year": 2012,
    # Other assumptions
    "discount_rate": 0.045, # irrelevant in this example
    "investment_cost_start_year": 2021, # irrelevant in this example
    "invest_from_zero": True, # irrelevant in this example
    "optimise_industrial_capacities": False, # irrelevant in this example
    "investment_technologies": [],
    "retirement_technologies": [],
    "constrained_energy_flows": [],
    "reoptimise_with_fixed_capacities": False, # capacities are always fixed in this example
    # CHP behaviour
    "fix_public_chp": True,
    "fix_industrial_chp": True,
    "share_space_heating": 0.75,
    # Electricity sector
    "prosumer_self_consumption": 0.2,
    "p_min_synchronous": 0, # irrelevant in this example - we set p_min_pu for thermal power plants
    "synchronous_carriers": [],
    # Technical details
    "inf": 100000,
    "space_heating_utilisation": 0.1, # irrelevant in this example
    "water_heating_utilisation": 1, # irrelevant in this example
    "other_heating_utilisation": 1, # irrelevant in this example
    "heat_capacity_utilisation": 0.2, # irrelevant in this example
    "light_vehicle_mobility_utilisation": 0.021, # irrelevant in this example
    "hydrogen_utilisation": 1, # irrelevant in this example
    "reverse_links": True,
    "solver": "highs",
    "solver_tolerance": 1e-6,
}

# %% [markdown]
# ### Prepare inputs

# %%
import logging
from pypsa_pl.build_network import load_and_preprocess_inputs


def custom_operation(inputs, params):

    def add_qualifier_to_technology(df, technology, qualifier):
        df.loc[df["technology"] == technology, "qualifier"] = qualifier
        return df

    # Identify solar PV roof as prosumer electricity source
    inputs["installed_capacity"] = add_qualifier_to_technology(
        inputs["installed_capacity"],
        "solar PV roof",
        "prosumer",
    )

    def remove_capacities(df, technologies):
        df = df[~df["technology"].isin(technologies)]
        return df

    # We do not model cross border electricity flows in this simplified example
    inputs["installed_capacity"] = remove_capacities(
        inputs["installed_capacity"],
        technologies=[
            "electricity export AC",
            "electricity import AC",
            "electricity export DC",
            "electricity import DC",
        ],
    )

    def subtract_grid_losses(df_flow):
        distribution_loss = 0.04

        # Subtract electricity grid losses
        is_electricity_final_use = df_flow["carrier"] == "electricity final use"
        df_flow.loc[is_electricity_final_use, "value"] *= 1 - distribution_loss
        logging.info(
            f"Subtracting {(distribution_loss * 100):.0f}% electricity distribution loss"
        )

        df_flow["value"] = df_flow["value"].round(1)

        return df_flow

    # The input electricity final use includes losses, so we need to subtract them
    inputs["annual_energy_flows"] = subtract_grid_losses(inputs["annual_energy_flows"])

    return inputs


inputs = load_and_preprocess_inputs(params, custom_operation=custom_operation)
# Out:
# 2024-11-09 00:19:41 [INFO] NumExpr defaulting to 8 threads.
# 2024-11-09 00:19:45 [INFO] Subtracting 4% electricity distribution loss

# %%
name = "technology_carrier_definitions"
# name = "technology_cost_data"
# name = "installed_capacity"
# name = "annual_energy_flows"
# name = "capacity_utilisation"
# name = "co2_cost"
# name = "final_use"

inputs[name].head()
# Out:
#               technology                carrier            aggregation parent  \
# 0  electricity final use  electricity final use  electricity final use    NaN
# 1       hard coal supply       hard coal supply       hard coal supply    NaN
# 2    hard coal power old        hard coal power        hard coal power    NaN
# 3     hard coal power SC        hard coal power        hard coal power    NaN
# 4          hard coal CHP          hard coal CHP          hard coal CHP    NaN
#
#   bus_carrier    input_carrier  output_carrier  output2_carrier  component  \
# 0         NaN  electricity out             NaN              NaN  Generator
# 1         NaN              NaN       hard coal              NaN  Generator
# 2         NaN        hard coal  electricity in              NaN       Link
# 3         NaN        hard coal  electricity in              NaN       Link
# 4         NaN        hard coal  electricity in              NaN       Link
#
#      color  order
# 0  #b6b6b7      1
# 1  #b5c6cf    110
# 2  #b5c6cf    111
# 3  #b5c6cf    112
# 4  #b5c6cf    113

# %% [markdown]
# ### Create PyPSA network

# %%
from pypsa_pl.build_network import create_custom_network

network = create_custom_network(params)

network
# Out:
# Empty PyPSA Network 'pypsa_pl_mini_opex_power'
# Components: none
# Snapshots: 1

# %% [markdown]
# ### Add snapshots

# %%
from pypsa_pl.build_network import add_snapshots

add_snapshots(network, params)

network.snapshots
# Out:
# Index(['2023-03-09 00:00:00', '2023-03-09 01:00:00', '2023-03-09 02:00:00',
#        '2023-03-09 03:00:00', '2023-03-09 04:00:00', '2023-03-09 05:00:00',
#        '2023-03-09 06:00:00', '2023-03-09 07:00:00', '2023-03-09 08:00:00',
#        '2023-03-09 09:00:00',
#        ...
#        '2023-11-01 14:00:00', '2023-11-01 15:00:00', '2023-11-01 16:00:00',
#        '2023-11-01 17:00:00', '2023-11-01 18:00:00', '2023-11-01 19:00:00',
#        '2023-11-01 20:00:00', '2023-11-01 21:00:00', '2023-11-01 22:00:00',
#        '2023-11-01 23:00:00'],
#       dtype='object', name='snapshot', length=672)

# %% [markdown]
# ### Add carriers

# %%
from pypsa_pl.build_network import add_carriers

add_carriers(network, inputs, params)

network.carriers
# Out:
#                               color  order              aggregation  \
# Carrier
# DSR reduction               #1b1c1e    291                      DSR
# battery large charger       #458aff    242            battery large
# battery large power         #458aff    241            battery large
# battery large storage       #458aff    240            battery large
# biogas CHP                  #816d66    183               biogas CHP
# biogas production           #816d66    181        biogas production
# biogas substrate supply     #816d66    180  biogas substrate supply
# biomass agriculture CHP     #ab9d99    171              biomass CHP
# biomass agriculture supply  #ab9d99    170           biomass supply
# biomass wood CHP            #ab9d99    162              biomass CHP
# biomass wood power          #ab9d99    161            biomass power
# biomass wood supply         #ab9d99    160           biomass supply
# electricity final use       #b6b6b7      1    electricity final use
# electricity grid            #b6b6b7   1201         electricity grid
# hard coal CHP               #b5c6cf    113            hard coal CHP
# hard coal power             #b5c6cf    111          hard coal power
# hard coal supply            #b5c6cf    110         hard coal supply
# hydro PSH power             #82b1ff    231                hydro PSH
# hydro PSH pump              #82b1ff    232                hydro PSH
# hydro PSH storage           #82b1ff    230                hydro PSH
# hydro ROR                   #2979ff    201                hydro ROR
# lignite power               #72a0b7    121            lignite power
# lignite supply              #72a0b7    120           lignite supply
# natural gas CHP             #4b7689    133          natural gas CHP
# natural gas power           #4b7689    131        natural gas power
# natural gas power peaker    #4b7689    132        natural gas power
# natural gas supply          #4b7689    130       natural gas supply
# nuclear power               #d6c0bd    151            nuclear power
# other CHP                   #263b46    141                other CHP
# other fuel supply           #263b46    140        other fuel supply
# solar PV ground             #f3b3fd    221          solar PV ground
# solar PV roof               #e040fb    222            solar PV roof
# wind offshore               #69f0ae    213            wind offshore
# wind onshore                #b9f6ca    211             wind onshore
#
#                             co2_emissions nice_name  max_growth  \
# Carrier
# DSR reduction                         NaN                   inf
# battery large charger                 NaN                   inf
# battery large power                   NaN                   inf
# battery large storage                 NaN                   inf
# biogas CHP                            NaN                   inf
# biogas production                     NaN                   inf
# biogas substrate supply               NaN                   inf
# biomass agriculture CHP               NaN                   inf
# biomass agriculture supply            NaN                   inf
# biomass wood CHP                      NaN                   inf
# biomass wood power                    NaN                   inf
# biomass wood supply                   NaN                   inf
# electricity final use                 NaN                   inf
# electricity grid                      NaN                   inf
# hard coal CHP                         NaN                   inf
# hard coal power                       NaN                   inf
# hard coal supply                     0.34                   inf
# hydro PSH power                       NaN                   inf
# hydro PSH pump                        NaN                   inf
# hydro PSH storage                     NaN                   inf
# hydro ROR                             NaN                   inf
# lignite power                         NaN                   inf
# lignite supply                       0.40                   inf
# natural gas CHP                       NaN                   inf
# natural gas power                     NaN                   inf
# natural gas power peaker              NaN                   inf
# natural gas supply                   0.20                   inf
# nuclear power                         NaN                   inf
# other CHP                             NaN                   inf
# other fuel supply                    0.27                   inf
# solar PV ground                       NaN                   inf
# solar PV roof                         NaN                   inf
# wind offshore                         NaN                   inf
# wind onshore                          NaN                   inf
#
#                             max_relative_growth
# Carrier
# DSR reduction                               0.0
# battery large charger                       0.0
# battery large power                         0.0
# battery large storage                       0.0
# biogas CHP                                  0.0
# biogas production                           0.0
# biogas substrate supply                     0.0
# biomass agriculture CHP                     0.0
# biomass agriculture supply                  0.0
# biomass wood CHP                            0.0
# biomass wood power                          0.0
# biomass wood supply                         0.0
# electricity final use                       0.0
# electricity grid                            0.0
# hard coal CHP                               0.0
# hard coal power                             0.0
# hard coal supply                            0.0
# hydro PSH power                             0.0
# hydro PSH pump                              0.0
# hydro PSH storage                           0.0
# hydro ROR                                   0.0
# lignite power                               0.0
# lignite supply                              0.0
# natural gas CHP                             0.0
# natural gas power                           0.0
# natural gas power peaker                    0.0
# natural gas supply                          0.0
# nuclear power                               0.0
# other CHP                                   0.0
# other fuel supply                           0.0
# solar PV ground                             0.0
# solar PV roof                               0.0
# wind offshore                               0.0
# wind onshore                                0.0

# %% [markdown]
# ### Add buses

# %%
from pypsa_pl.build_network import add_buses_and_areas

add_buses_and_areas(network, inputs, params)

network.buses
# Out:
#                              area                    carrier qualifier  v_nom  \
# Bus
# PL battery large electricity   PL  battery large electricity              1.0
# PL biogas                      PL                     biogas              1.0
# PL biogas substrate            PL           biogas substrate              1.0
# PL biomass wood                PL               biomass wood              1.0
# PL electricity in              PL             electricity in              1.0
# PL electricity out             PL            electricity out              1.0
# PL hard coal                   PL                  hard coal              1.0
# PL hydro PSH electricity       PL      hydro PSH electricity              1.0
# PL lignite                     PL                    lignite              1.0
# PL natural gas                 PL                natural gas              1.0
# PL other fuel                  PL                 other fuel              1.0
#
#                              type    x    y unit  v_mag_pu_set  v_mag_pu_min  \
# Bus
# PL battery large electricity       0.0  0.0                1.0           0.0
# PL biogas                          0.0  0.0                1.0           0.0
# PL biogas substrate                0.0  0.0                1.0           0.0
# PL biomass wood                    0.0  0.0                1.0           0.0
# PL electricity in                  0.0  0.0                1.0           0.0
# PL electricity out                 0.0  0.0                1.0           0.0
# PL hard coal                       0.0  0.0                1.0           0.0
# PL hydro PSH electricity           0.0  0.0                1.0           0.0
# PL lignite                         0.0  0.0                1.0           0.0
# PL natural gas                     0.0  0.0                1.0           0.0
# PL other fuel                      0.0  0.0                1.0           0.0
#
#                               v_mag_pu_max control generator sub_network
# Bus
# PL battery large electricity           inf      PQ
# PL biogas                              inf      PQ
# PL biogas substrate                    inf      PQ
# PL biomass wood                        inf      PQ
# PL electricity in                      inf      PQ
# PL electricity out                     inf      PQ
# PL hard coal                           inf      PQ
# PL hydro PSH electricity               inf      PQ
# PL lignite                             inf      PQ
# PL natural gas                         inf      PQ
# PL other fuel                          inf      PQ

# %% [markdown]
# ### Add generating, consuming, and storing capacity (generators, links, stores)

# %% [markdown]
# #### Process installed capacity data and specify the relevant attributes

# %%
from pypsa_pl.build_network import process_capacity_data

df_cap = process_capacity_data(inputs, params)

df_cap.head()
# Out:
#                             name area area2             technology  \
# 0  PL battery large charger 2023   PL    PL  battery large charger
# 1    PL battery large power 2023   PL    PL    battery large power
# 2  PL battery large storage 2023   PL   NaN  battery large storage
# 3  PL biogas CHP industrial 2023   PL    PL             biogas CHP
# 4      PL biogas CHP public 2023   PL    PL             biogas CHP
#
#     qualifier  build_year  retire_year  cumulative    nom  \
# 0         NaN        2023       2023.0        True  140.0
# 1         NaN        2023       2023.0        True  150.0
# 2         NaN        2023       2023.0        True  600.0
# 3  industrial        2023       2023.0        True   70.0
# 4      public        2023       2023.0        True  210.0
#
#                  carrier  ... e_nom_max p_set p_set_annual  p_max_pu  \
# 0  battery large charger  ...       NaN   NaN          NaN       1.0
# 1    battery large power  ...       NaN   NaN          NaN       1.0
# 2  battery large storage  ...     600.0   NaN          NaN       1.0
# 3             biogas CHP  ...       NaN  34.3          NaN       1.0
# 4             biogas CHP  ...       NaN   NaN        113.4       1.0
#
#    p_min_pu p_set_pu_annual e_min_pu  e_max_pu  p_min_pu_annual  \
# 0       0.0             NaN      0.0       1.0              0.0
# 1       0.0             NaN      0.0       1.0              0.0
# 2       0.0             NaN      0.0       1.0              0.0
# 3       0.0             NaN      0.0       1.0              0.0
# 4       0.0            0.54      0.0       1.0              0.0
#
#                         parent
# 0  PL battery large power 2023
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
# [5 rows x 48 columns]

# %% [markdown]
# #### Specify which attributes are time dependent

# %%
from pypsa_pl.define_time_dependent_attributes import (
    define_time_dependent_attributes,
)


df_attr_t = define_time_dependent_attributes(df_cap, params)

df_attr_t
# Out:
#                   carrier                technology   qualifier attribute  \
# 0   electricity final use     electricity final use        none     p_set
# 1              biogas CHP                biogas CHP      public     p_set
# 2        biomass wood CHP          biomass wood CHP      public     p_set
# 3           hard coal CHP             hard coal CHP      public     p_set
# 4         natural gas CHP  natural gas CHP CCGT old      public     p_set
# 5         natural gas CHP      natural gas CHP CCGT      public     p_set
# 6         natural gas CHP       natural gas CHP old      public     p_set
# 7         solar PV ground           solar PV ground        none  p_max_pu
# 8           solar PV roof             solar PV roof    prosumer  p_max_pu
# 9            wind onshore              wind onshore        none  p_max_pu
# 10           wind onshore          wind onshore old        none  p_max_pu
# 11             biogas CHP                biogas CHP  industrial     p_set
# 12      biogas production         biogas production  industrial     p_set
# 13       biomass wood CHP          biomass wood CHP  industrial     p_set
# 14          hard coal CHP             hard coal CHP  industrial     p_set
# 15              hydro ROR                 hydro ROR        none     p_set
# 16        natural gas CHP  natural gas CHP CCGT old  industrial     p_set
# 17        natural gas CHP       natural gas CHP old  industrial     p_set
# 18              other CHP                 other CHP  industrial     p_set
#
#                           profile_type
# 0   electricity final use load profile
# 1   public heat final use load profile
# 2   public heat final use load profile
# 3   public heat final use load profile
# 4   public heat final use load profile
# 5   public heat final use load profile
# 6   public heat final use load profile
# 7            vres availability profile
# 8            vres availability profile
# 9            vres availability profile
# 10           vres availability profile
# 11               constant load profile
# 12               constant load profile
# 13               constant load profile
# 14               constant load profile
# 15               constant load profile
# 16               constant load profile
# 17               constant load profile
# 18               constant load profile

# %% [markdown]
# #### Create actual components and fill them with data

# %%
from pypsa_pl.build_network import add_capacities

add_capacities(network, df_cap, df_attr_t, params)

# %%
network.generators.head()
# Out:
#                                                  bus area  \
# Generator
# PL biogas substrate supply 2023  PL biogas substrate   PL
# PL biomass wood supply 2023          PL biomass wood   PL
# PL electricity final use 2023     PL electricity out   PL
# PL hard coal supply 2023                PL hard coal   PL
# PL hydro ROR 2023                  PL electricity in   PL
#
#                                                  carrier  \
# Generator
# PL biogas substrate supply 2023  biogas substrate supply
# PL biomass wood supply 2023          biomass wood supply
# PL electricity final use 2023      electricity final use
# PL hard coal supply 2023                hard coal supply
# PL hydro ROR 2023                              hydro ROR
#
#                                               technology qualifier  \
# Generator
# PL biogas substrate supply 2023  biogas substrate supply
# PL biomass wood supply 2023          biomass wood supply
# PL electricity final use 2023      electricity final use
# PL hard coal supply 2023                hard coal supply
# PL hydro ROR 2023                              hydro ROR
#
#                                              aggregation     p_nom  \
# Generator
# PL biogas substrate supply 2023  biogas substrate supply  100000.0
# PL biomass wood supply 2023               biomass supply  100000.0
# PL electricity final use 2023      electricity final use  100000.0
# PL hard coal supply 2023                hard coal supply  100000.0
# PL hydro ROR 2023                              hydro ROR     600.0
#
#                                  p_nom_extendable  p_nom_min  p_nom_max  ...  \
# Generator                                                                ...
# PL biogas substrate supply 2023             False   100000.0   100000.0  ...
# PL biomass wood supply 2023                 False   100000.0   100000.0  ...
# PL electricity final use 2023               False   100000.0   100000.0  ...
# PL hard coal supply 2023                    False   100000.0   100000.0  ...
# PL hydro ROR 2023                           False      600.0      600.0  ...
#
#                                  min_up_time  min_down_time  up_time_before  \
# Generator
# PL biogas substrate supply 2023            0              0               1
# PL biomass wood supply 2023                0              0               1
# PL electricity final use 2023              0              0               1
# PL hard coal supply 2023                   0              0               1
# PL hydro ROR 2023                          0              0               1
#
#                                  down_time_before  ramp_limit_up  \
# Generator
# PL biogas substrate supply 2023                 0            NaN
# PL biomass wood supply 2023                     0            NaN
# PL electricity final use 2023                   0            NaN
# PL hard coal supply 2023                        0            NaN
# PL hydro ROR 2023                               0            NaN
#
#                                  ramp_limit_down  ramp_limit_start_up  \
# Generator
# PL biogas substrate supply 2023              NaN                  1.0
# PL biomass wood supply 2023                  NaN                  1.0
# PL electricity final use 2023                NaN                  1.0
# PL hard coal supply 2023                     NaN                  1.0
# PL hydro ROR 2023                            NaN                  1.0
#
#                                  ramp_limit_shut_down  weight  p_nom_opt
# Generator
# PL biogas substrate supply 2023                   1.0     1.0        0.0
# PL biomass wood supply 2023                       1.0     1.0        0.0
# PL electricity final use 2023                     1.0     1.0        0.0
# PL hard coal supply 2023                          1.0     1.0        0.0
# PL hydro ROR 2023                                 1.0     1.0        0.0
#
# [5 rows x 48 columns]

# %%
network.generators[["variable_cost", "co2_cost", "marginal_cost"]]
# Out:
#                                  variable_cost  co2_cost  marginal_cost
# Generator
# PL biogas substrate supply 2023          180.0       0.0          180.0
# PL biomass wood supply 2023              120.0       0.0          120.0
# PL electricity final use 2023              0.0       0.0            0.0
# PL hard coal supply 2023                 120.0     129.2          249.2
# PL hydro ROR 2023                          0.0       0.0            0.0
# PL lignite supply 2023                    10.0     152.0          162.0
# PL natural gas supply 2023               210.0      76.0          286.0
# PL other fuel supply 2023                180.0     102.6          282.6
# PL solar PV ground 2023                    0.0       0.0            0.0
# PL solar PV roof 2023                      0.0       0.0            0.0
# PL wind onshore 2023                      13.0       0.0           13.0
# PL wind onshore old 2023                  18.0       0.0           18.0

# %%
network.generators_t.p_max_pu.head()
# Out:
# Generator            PL solar PV ground 2023  PL solar PV roof 2023  \
# snapshot
# 2023-03-09 00:00:00                      0.0                    0.0
# 2023-03-09 01:00:00                      0.0                    0.0
# 2023-03-09 02:00:00                      0.0                    0.0
# 2023-03-09 03:00:00                      0.0                    0.0
# 2023-03-09 04:00:00                      0.0                    0.0
#
# Generator            PL wind onshore 2023  PL wind onshore old 2023
# snapshot
# 2023-03-09 00:00:00              0.397477                  0.354552
# 2023-03-09 01:00:00              0.384946                  0.342663
# 2023-03-09 02:00:00              0.373421                  0.331774
# 2023-03-09 03:00:00              0.359752                  0.318914
# 2023-03-09 04:00:00              0.367119                  0.325837

# %%
network.generators_t.p_set.head()
# Out:
# Generator            PL electricity final use 2023  PL hydro ROR 2023
# snapshot
# 2023-03-09 00:00:00                   16145.605023              276.0
# 2023-03-09 01:00:00                   15587.694064              276.0
# 2023-03-09 02:00:00                   15384.817352              276.0
# 2023-03-09 03:00:00                   15367.910959              276.0
# 2023-03-09 04:00:00                   15587.694064              276.0

# %%
network.links.head()
# Out:
#                                                               bus0  \
# Link
# PL battery large charger 2023         PL battery large electricity
# PL battery large power 2023                      PL electricity in
# PL biogas CHP industrial 2023                    PL electricity in
# PL biogas CHP public 2023                        PL electricity in
# PL biogas production industrial 2023                     PL biogas
#
#                                                               bus1 bus2 area  \
# Link
# PL battery large charger 2023                   PL electricity out        PL
# PL battery large power 2023           PL battery large electricity        PL
# PL biogas CHP industrial 2023                            PL biogas        PL
# PL biogas CHP public 2023                                PL biogas        PL
# PL biogas production industrial 2023           PL biogas substrate        PL
#
#                                      area2                carrier  \
# Link
# PL battery large charger 2023           PL  battery large charger
# PL battery large power 2023             PL    battery large power
# PL biogas CHP industrial 2023           PL             biogas CHP
# PL biogas CHP public 2023               PL             biogas CHP
# PL biogas production industrial 2023    PL      biogas production
#
#                                                  technology   qualifier  \
# Link
# PL battery large charger 2023         battery large charger
# PL battery large power 2023             battery large power
# PL biogas CHP industrial 2023                    biogas CHP  industrial
# PL biogas CHP public 2023                        biogas CHP      public
# PL biogas production industrial 2023      biogas production  industrial
#
#                                             aggregation  p_nom  ...  \
# Link                                                            ...
# PL battery large charger 2023             battery large  140.0  ...
# PL battery large power 2023               battery large  150.0  ...
# PL biogas CHP industrial 2023                biogas CHP   70.0  ...
# PL biogas CHP public 2023                    biogas CHP  210.0  ...
# PL biogas production industrial 2023  biogas production  180.0  ...
#
#                                       shut_down_cost  min_up_time  \
# Link
# PL battery large charger 2023                    0.0            0
# PL battery large power 2023                      0.0            0
# PL biogas CHP industrial 2023                    0.0            0
# PL biogas CHP public 2023                        0.0            0
# PL biogas production industrial 2023             0.0            0
#
#                                       min_down_time  up_time_before  \
# Link
# PL battery large charger 2023                     0               1
# PL battery large power 2023                       0               1
# PL biogas CHP industrial 2023                     0               1
# PL biogas CHP public 2023                         0               1
# PL biogas production industrial 2023              0               1
#
#                                       down_time_before  ramp_limit_up  \
# Link
# PL battery large charger 2023                        0            NaN
# PL battery large power 2023                          0            NaN
# PL biogas CHP industrial 2023                        0            NaN
# PL biogas CHP public 2023                            0            NaN
# PL biogas production industrial 2023                 0            NaN
#
#                                       ramp_limit_down  ramp_limit_start_up  \
# Link
# PL battery large charger 2023                     NaN                  1.0
# PL battery large power 2023                       NaN                  1.0
# PL biogas CHP industrial 2023                     NaN                  1.0
# PL biogas CHP public 2023                         NaN                  1.0
# PL biogas production industrial 2023              NaN                  1.0
#
#                                       ramp_limit_shut_down  p_nom_opt
# Link
# PL battery large charger 2023                          1.0        0.0
# PL battery large power 2023                            1.0        0.0
# PL biogas CHP industrial 2023                          1.0        0.0
# PL biogas CHP public 2023                              1.0        0.0
# PL biogas production industrial 2023                   1.0        0.0
#
# [5 rows x 50 columns]

# %%
network.links_t.p_set.head()
# Out:
# Link                 PL biogas CHP industrial 2023  PL biogas CHP public 2023  \
# snapshot
# 2023-03-09 00:00:00                          -34.3                 -183.39615
# 2023-03-09 01:00:00                          -34.3                 -184.24665
# 2023-03-09 02:00:00                          -34.3                 -184.24665
# 2023-03-09 03:00:00                          -34.3                 -187.73370
# 2023-03-09 04:00:00                          -34.3                 -197.93970
#
# Link                 PL biogas production industrial 2023  \
# snapshot
# 2023-03-09 00:00:00                                 -88.2
# 2023-03-09 01:00:00                                 -88.2
# 2023-03-09 02:00:00                                 -88.2
# 2023-03-09 03:00:00                                 -88.2
# 2023-03-09 04:00:00                                 -88.2
#
# Link                 PL biomass wood CHP industrial 2023  \
# snapshot
# 2023-03-09 00:00:00                               -182.0
# 2023-03-09 01:00:00                               -182.0
# 2023-03-09 02:00:00                               -182.0
# 2023-03-09 03:00:00                               -182.0
# 2023-03-09 04:00:00                               -182.0
#
# Link                 PL biomass wood CHP public 2023  \
# snapshot
# 2023-03-09 00:00:00                           -260.0
# 2023-03-09 01:00:00                           -260.0
# 2023-03-09 02:00:00                           -260.0
# 2023-03-09 03:00:00                           -260.0
# 2023-03-09 04:00:00                           -260.0
#
# Link                 PL hard coal CHP industrial 2023  \
# snapshot
# 2023-03-09 00:00:00                            -236.9
# 2023-03-09 01:00:00                            -236.9
# 2023-03-09 02:00:00                            -236.9
# 2023-03-09 03:00:00                            -236.9
# 2023-03-09 04:00:00                            -236.9
#
# Link                 PL hard coal CHP public 2023  \
# snapshot
# 2023-03-09 00:00:00                    -2265.4438
# 2023-03-09 01:00:00                    -2275.9498
# 2023-03-09 02:00:00                    -2275.9498
# 2023-03-09 03:00:00                    -2319.0244
# 2023-03-09 04:00:00                    -2445.0964
#
# Link                 PL natural gas CHP CCGT old industrial 2023  \
# snapshot
# 2023-03-09 00:00:00                                       -551.2
# 2023-03-09 01:00:00                                       -551.2
# 2023-03-09 02:00:00                                       -551.2
# 2023-03-09 03:00:00                                       -551.2
# 2023-03-09 04:00:00                                       -551.2
#
# Link                 PL natural gas CHP CCGT old public 2023  \
# snapshot
# 2023-03-09 00:00:00                                -450.8893
# 2023-03-09 01:00:00                                -452.9803
# 2023-03-09 02:00:00                                -452.9803
# 2023-03-09 03:00:00                                -461.5534
# 2023-03-09 04:00:00                                -486.6454
#
# Link                 PL natural gas CHP CCGT public 2023  \
# snapshot
# 2023-03-09 00:00:00                            -344.7977
# 2023-03-09 01:00:00                            -346.3967
# 2023-03-09 02:00:00                            -346.3967
# 2023-03-09 03:00:00                            -352.9526
# 2023-03-09 04:00:00                            -372.1406
#
# Link                 PL natural gas CHP old industrial 2023  \
# snapshot
# 2023-03-09 00:00:00                                  -234.0
# 2023-03-09 01:00:00                                  -234.0
# 2023-03-09 02:00:00                                  -234.0
# 2023-03-09 03:00:00                                  -234.0
# 2023-03-09 04:00:00                                  -234.0
#
# Link                 PL natural gas CHP old public 2023  \
# snapshot
# 2023-03-09 00:00:00                           -822.2099
# 2023-03-09 01:00:00                           -826.0229
# 2023-03-09 02:00:00                           -826.0229
# 2023-03-09 03:00:00                           -841.6562
# 2023-03-09 04:00:00                           -887.4122
#
# Link                 PL other CHP industrial 2023
# snapshot
# 2023-03-09 00:00:00                        -275.0
# 2023-03-09 01:00:00                        -275.0
# 2023-03-09 02:00:00                        -275.0
# 2023-03-09 03:00:00                        -275.0
# 2023-03-09 04:00:00                        -275.0

# %%
network.links.p_max_pu
# Out:
# Link
# PL battery large charger 2023                 -0.00
# PL battery large power 2023                   -0.00
# PL biogas CHP industrial 2023                 -0.00
# PL biogas CHP public 2023                     -0.00
# PL biogas production industrial 2023          -0.00
# PL biogas production public 2023              -0.00
# PL biomass wood CHP industrial 2023           -0.00
# PL biomass wood CHP public 2023               -0.00
# PL biomass wood power public 2023             -0.25
# PL electricity grid 2023                      -0.00
# PL hard coal CHP industrial 2023              -0.00
# PL hard coal CHP public 2023                  -0.00
# PL hard coal power SC public 2023             -0.25
# PL hard coal power old public 2023            -0.25
# PL hydro PSH power 2023                       -0.00
# PL hydro PSH pump 2023                        -0.00
# PL lignite power SC public 2023               -0.25
# PL lignite power old public 2023              -0.25
# PL natural gas CHP CCGT old industrial 2023   -0.00
# PL natural gas CHP CCGT old public 2023       -0.00
# PL natural gas CHP CCGT public 2023           -0.00
# PL natural gas CHP old industrial 2023        -0.00
# PL natural gas CHP old public 2023            -0.00
# PL other CHP industrial 2023                  -0.00
# Name: p_max_pu, dtype: float64

# %%
network.stores.head()
# Out:
#                                                         bus area  \
# Store
# PL battery large storage 2023  PL battery large electricity   PL
# PL hydro PSH storage 2023          PL hydro PSH electricity   PL
#
#                                              carrier             technology  \
# Store
# PL battery large storage 2023  battery large storage  battery large storage
# PL hydro PSH storage 2023          hydro PSH storage      hydro PSH storage
#
#                               qualifier    aggregation   e_nom  \
# Store
# PL battery large storage 2023            battery large   600.0
# PL hydro PSH storage 2023                    hydro PSH  8470.0
#
#                                e_nom_extendable  e_nom_min  e_nom_max  ...  \
# Store                                                                  ...
# PL battery large storage 2023             False      600.0      600.0  ...
# PL hydro PSH storage 2023                 False     8470.0     8470.0  ...
#
#                                type  e_nom_mod  e_initial  \
# Store
# PL battery large storage 2023              0.0        0.0
# PL hydro PSH storage 2023                  0.0        0.0
#
#                                e_initial_per_period  e_cyclic_per_period  \
# Store
# PL battery large storage 2023                 False                 True
# PL hydro PSH storage 2023                     False                 True
#
#                                p_set  q_set  sign  marginal_cost_quadratic  \
# Store
# PL battery large storage 2023    0.0    0.0   1.0                      0.0
# PL hydro PSH storage 2023        0.0    0.0   1.0                      0.0
#
#                                e_nom_opt
# Store
# PL battery large storage 2023        0.0
# PL hydro PSH storage 2023            0.0
#
# [2 rows x 35 columns]

# %% [markdown]
# ### Add flow constraints

# %%
from pypsa_pl.build_network import add_energy_flow_constraints

add_energy_flow_constraints(network, inputs, params)

# No flow constraints are added by default
network.global_constraints
# Out:
# Empty DataFrame
# Columns: [type, investment_period, area, carrier_attribute, sense, constant, mu]
# Index: []

# %% [markdown]
# ### Save input network

# %%
from pypsa_pl.config import data_dir

os.makedirs(data_dir("runs", params["run_name"]), exist_ok=True)
network.export_to_csv_folder(data_dir("runs", params["run_name"], "input_network"))
# Out:
# 2024-11-09 00:19:51 [INFO] Exported network input_network has stores, areas, buses, carriers, links, generators

# %% [markdown]
# ### Solve the model

# %%
from pypsa_pl.optimise_network import optimise_network

optimise_network(network, params)
# Out:
# 2024-11-09 00:19:51 [INFO] Repeating time-series for each investment period and converting snapshots to a pandas.MultiIndex.
# 2024-11-09 00:19:56 [INFO]  Solve problem using Highs solver
# 2024-11-09 00:19:56 [INFO] Solver options:
#  - threads: 4
#  - solver: ipm
#  - run_crossover: off
#  - small_matrix_value: 1e-07
#  - large_matrix_value: 1000000000000.0
#  - primal_feasibility_tolerance: 9.999999999999999e-06
#  - dual_feasibility_tolerance: 9.999999999999999e-06
#  - ipm_optimality_tolerance: 1e-06
#  - parallel: on
#  - random_seed: 0
# 2024-11-09 00:19:56 [INFO] Writing objective.
# Writing constraints.: 100%|██████████| 12/12 [00:01<00:00,  9.22it/s]
# Writing continuous variables.: 100%|██████████| 4/4 [00:00<00:00, 17.89it/s]
# 2024-11-09 00:19:58 [INFO]  Writing time: 1.67s
# 2024-11-09 00:19:59 [INFO] Log file at /tmp/highs.log.
# Running HiGHS 1.7.2 (git hash: 184e327): Copyright (c) 2024 HiGHS under MIT licence terms
# Coefficient ranges:
#   Matrix [1e+00, 4e+00]
#   Cost   [3e+01, 4e+03]
#   Bound  [0e+00, 0e+00]
#   RHS    [6e+00, 3e+05]
# Presolving model
# 4034 rows, 11480 cols, 18872 nonzeros  0s
# 2018 rows, 9464 cols, 14840 nonzeros  0s
# 2009 rows, 8945 cols, 14269 nonzeros  0s
# Presolve : Reductions: rows 2009(-67882); columns 8945(-17935); elements 14269(-94595)
# Solving the presolved LP
# IPX model has 2009 rows, 8945 columns and 14269 nonzeros
# Input
#     Number of variables:                                8945
#     Number of free variables:                           0
#     Number of constraints:                              2009
#     Number of equality constraints:                     2007
#     Number of matrix entries:                           14269
#     Matrix range:                                       [1e+00, 1e+00]
#     RHS range:                                          [2e+03, 2e+05]
#     Objective range:                                    [1e+02, 2e+04]
#     Bounds range:                                       [1e+01, 1e+04]
# Preprocessing
#     Dualized model:                                     no
#     Number of dense columns:                            0
#     Range of scaling factors:                           [1.00e+00, 1.00e+00]
# IPX version 1.0
# Interior Point Solve
#  Iter     P.res    D.res            P.obj           D.obj        mu     Time
#    0   2.97e+03 9.46e+03   4.68110377e+10 -1.39023340e+11  3.66e+07       0s
#    1   4.54e+02 2.01e+03   5.29212851e+10 -4.06582626e+10  7.70e+06       0s
#    2   1.12e+02 1.07e+03   5.24113459e+10 -1.26212107e+10  3.80e+06       0s
#    3   2.85e+01 1.85e+02   4.86643359e+10  3.45832387e+10  7.73e+05       0s
#    4   9.51e+00 6.45e+01   4.63605924e+10  4.06374556e+10  3.01e+05       0s
#    5   3.60e+00 2.41e+01   4.55446163e+10  4.27555498e+10  1.44e+05       0s
#    6   1.71e+00 9.49e+00   4.51890594e+10  4.37992045e+10  7.24e+04       0s
#  Constructing starting basis...
#    7   4.76e-01 2.37e+00   4.49279506e+10  4.43541663e+10  3.26e+04       0s
#    8   1.68e-01 1.01e+00   4.48
# 2024-11-09 00:20:00 [INFO]  Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 26880 primals, 69891 duals
# Objective: 7.43e+10
# Solver model: available
# Solver message: optimal
# 251810e+10  4.45344696e+10  1.64e+04       0s
#    9   2.70e-02 1.15e-01   4.47657056e+10  4.46788244e+10  4.89e+03       0s
#   10   5.69e-03 2.62e-02   4.47435369e+10  4.47170048e+10  1.49e+03       0s
#   11   1.06e-03 7.18e-03   4.47366626e+10  4.47284179e+10  4.62e+02       0s
#   12   2.70e-04 4.48e-04   4.47350574e+10  4.47332987e+10  9.86e+01       0s
#   13   5.41e-05 5.21e-05   4.47343781e+10  4.47340557e+10  1.81e+01       0s
#   14*  4.29e-07 9.36e-06   4.47341907e+10  4.47341640e+10  1.49e+00       0s
# Summary
#     Runtime:                                            0.18s
#     Status interior point solve:                        optimal
#     Status crossover:                                   not run
#     objective value:                                    4.47341907e+10
#     interior solution primal residual (abs/rel):        4.29e-07 / 1.77e-12
#     interior solution dual residual (abs/rel):          9.36e-06 / 6.22e-10
#     interior solution objective gap (abs/rel):          2.67e+04 / 5.96e-07
# Ipx: IPM       optimal
# Model   status      : Optimal
# IPM       iterations: 14
# Objective value     :  7.4339790209e+10
# HiGHS run time      :          0.43
# 2024-11-09 00:20:00 [INFO] The shadow-prices of the constraints Generator-fix-p-lower, Generator-fix-p-upper, Generator-p_set, Link-fix-p-lower, Link-fix-p-upper, Link-p_set, Store-fix-e-lower, Store-fix-e-upper, Store-energy_balance were not assigned to the network.
# [PyPSA Network 'pypsa_pl_mini_opex_power'
#  Components:
#   - Area: 1
#   - Bus: 11
#   - Carrier: 34
#   - Generator: 12
#   - Link: 24
#   - Store: 2
#  Snapshots: 672]

# %% [markdown]
# ### Save output network

# %%
network.export_to_csv_folder(data_dir("runs", params["run_name"], "output_network"))
# Out:
# 2024-11-09 00:20:01 [INFO] Exported network output_network has stores, areas, buses, carriers, links, generators

# %% [markdown]
# ### Analyse results

# %%
import pandas as pd


def append_annual_sum(df, value_cols=["value"]):
    agg_columns = ["carrier", "aggregation", "fuel"]
    agg = df.columns.intersection(agg_columns)
    assert len(agg) == 1
    agg = agg[0]
    return pd.concat(
        [
            df,
            df.groupby("year")
            .agg({agg: lambda x: "SUM", **{col: "sum" for col in value_cols}})
            .reset_index(),
        ]
    )

# %% [markdown]
# #### Display statistics

# %%
from pypsa_pl.process_output_network import calculate_statistics

df_stat = calculate_statistics(network)
df_stat
# Out:
#     year  component area              aggregation                  carrier  \
# 0   2023  Generator   PL  biogas substrate supply  biogas substrate supply
# 1   2023  Generator   PL           biomass supply      biomass wood supply
# 2   2023  Generator   PL    electricity final use    electricity final use
# 3   2023  Generator   PL         hard coal supply         hard coal supply
# 4   2023  Generator   PL                hydro ROR                hydro ROR
# 5   2023  Generator   PL           lignite supply           lignite supply
# 6   2023  Generator   PL       natural gas supply       natural gas supply
# 7   2023  Generator   PL        other fuel supply        other fuel supply
# 8   2023  Generator   PL          solar PV ground          solar PV ground
# 9   2023  Generator   PL            solar PV roof            solar PV roof
# 10  2023  Generator   PL             wind onshore             wind onshore
# 11  2023  Generator   PL             wind onshore             wind onshore
# 12  2023       Link   PL            battery large    battery large charger
# 13  2023       Link   PL            battery large      battery large power
# 14  2023       Link   PL               biogas CHP               biogas CHP
# 15  2023       Link   PL               biogas CHP               biogas CHP
# 16  2023       Link   PL        biogas production        biogas production
# 17  2023       Link   PL        biogas production        biogas production
# 18  2023       Link   PL              biomass CHP         biomass wood CHP
# 19  2023       Link   PL              biomass CHP         biomass wood CHP
# 20  2023       Link   PL            biomass power       biomass wood power
# 21  2023       Link   PL         electricity grid         electricity grid
# 22  2023       Link   PL            hard coal CHP            hard coal CHP
# 23  2023       Link   PL            hard coal CHP            hard coal CHP
# 24  2023       Link   PL          hard coal power          hard coal power
# 25  2023       Link   PL          hard coal power          hard coal power
# 26  2023       Link   PL                hydro PSH          hydro PSH power
# 27  2023       Link   PL                hydro PSH           hydro PSH pump
# 28  2023       Link   PL            lignite power            lignite power
# 29  2023       Link   PL            lignite power            lignite power
# 30  2023       Link   PL          natural gas CHP          natural gas CHP
# 31  2023       Link   PL          natural gas CHP          natural gas CHP
# 32  2023       Link   PL          natural gas CHP          natural gas CHP
# 33  2023       Link   PL          natural gas CHP          natural gas CHP
# 34  2023       Link   PL          natural gas CHP          natural gas CHP
# 35  2023       Link   PL                other CHP                other CHP
# 36  2023      Store   PL            battery large    battery large storage
# 37  2023      Store   PL                hydro PSH        hydro PSH storage
#
#                   technology   qualifier  Optimal Capacity  \
# 0    biogas substrate supply                      100000.0
# 1        biomass wood supply                      100000.0
# 2      electricity final use                      100000.0
# 3           hard coal supply                      100000.0
# 4                  hydro ROR                         600.0
# 5             lignite supply                      100000.0
# 6         natural gas supply                      100000.0
# 7          other fuel supply                      100000.0
# 8            solar PV ground                        6380.0
# 9              solar PV roof    prosumer           10670.0
# 10              wind onshore                        3050.0
# 11          wind onshore old                        6380.0
# 12     battery large charger                         140.0
# 13       battery large power                         150.0
# 14                biogas CHP  industrial              70.0
# 15                biogas CHP      public             210.0
# 16         biogas production  industrial             180.0
# 17         biogas production      public             520.0
# 18          biomass wood CHP  industrial             200.0
# 19          biomass wood CHP      public             260.0
# 20        biomass wood power      public             400.0
# 21          electricity grid                      100000.0
# 22             hard coal CHP  industrial            1030.0
# 23             hard coal CHP      public            4120.0
# 24        hard coal power SC      public            4050.0
# 25       hard coal power old      public           11090.0
# 26           hydro PSH power                        1790.0
# 27            hydro PSH pump                        1130.0
# 28          lignite power SC      public            1710.0
# 29         lignite power old      public            5930.0
# 30      natural gas CHP CCGT      public             520.0
# 31  natural gas CHP CCGT old  industrial            1060.0
# 32  natural gas CHP CCGT old      public             680.0
# 33       natural gas CHP old  industrial             450.0
# 34       natural gas CHP old      public            1240.0
# 35                 other CHP  industrial             550.0
# 36     battery large storage                         600.0
# 37         hydro PSH storage                        8470.0
#
#     Installed Capacity  Capacity Factor      Dispatch  Transmission  \
# 0             100000.0         0.003992  3.496670e+06           0.0
# 1             100000.0         0.024738  2.167006e+07           0.0
# 2             100000.0         0.169061 -1.480971e+08           0.0
# 3             100000.0         0.171842  1.505335e+08           0.0
# 4                600.0         0.460000  2.417760e+06           0.0
# 5             100000.0         0.135045  1.182996e+08           0.0
# 6             100000.0         0.037327  3.269809e+07           0.0
# 7             100000.0         0.008088  7.085294e+06           0.0
# 8               6380.0         0.118749  6.636726e+06           0.0
# 9              10670.0         0.088000  8.225290e+06           0.0
# 10              3050.0         0.298815  7.983730e+06           0.0
# 11              6380.0         0.249211  1.392811e+07           0.0
# 12               140.0         0.100055 -1.363419e+04           0.0
# 13               150.0         0.093373  0.000000e+00           0.0
# 14                70.0         0.490000 -4.323808e+05           0.0
# 15               210.0         0.538054 -1.424351e+06           0.0
# 16               180.0         0.490000 -8.584800e+04           0.0
# 17               520.0         0.521244 -2.638190e+05           0.0
# 18               200.0         0.910000 -4.537680e+06           0.0
# 19               260.0         0.723699 -4.691307e+06           0.0
# 20               400.0         0.840042 -6.254953e+06           0.0
# 21            100000.0         0.170781 -6.233516e+06           0.0
# 22              1030.0         0.230000 -5.610845e+06           0.0
# 23              4120.0         0.339999 -3.317706e+07           0.0
# 24              4050.0         0.288153 -1.355152e+07           0.0
# 25             11090.0         0.250094 -4.932863e+07           0.0
# 26              1790.0         0.061199  0.000000e+00           0.0
# 27              1130.0         0.096944 -4.112715e+05           0.0
# 28              1710.0         0.813434 -1.827737e+07           0.0
# 29              5930.0         0.558000 -5.885102e+07           0.0
# 30               520.0         0.409999 -1.723962e+06           0.0
# 31              1060.0         0.520000 -4.457088e+06           0.0
# 32               680.0         0.409999 -2.254412e+06           0.0
# 33               450.0         0.520000 -2.717230e+06           0.0
# 34              1240.0         0.409999 -5.903568e+06           0.0
# 35               550.0         0.500000 -4.676294e+06           0.0
# 36               600.0         0.492133 -1.869763e+01           0.0
# 37              8470.0         0.456717 -7.033182e-01           0.0
#
#       Withdrawal        Supply   Curtailment  Capital Expenditure  \
# 0   0.000000e+00  3.496670e+06           NaN         0.000000e+00
# 1   0.000000e+00  2.167006e+07           NaN         0.000000e+00
# 2   1.480971e+08  0.000000e+00           NaN         0.000000e+00
# 3   0.000000e+00  1.505335e+08           NaN         0.000000e+00
# 4   0.000000e+00  2.417760e+06           NaN         0.000000e+00
# 5   0.000000e+00  1.182996e+08           NaN         0.000000e+00
# 6   0.000000e+00  3.269809e+07           NaN         0.000000e+00
# 7   0.000000e+00  7.085294e+06           NaN         0.000000e+00
# 8   0.000000e+00  6.636726e+06  6.992995e+04         3.445200e+08
# 9   0.000000e+00  8.225290e+06  4.403355e-06         7.148900e+08
# 10  0.000000e+00  7.983730e+06  2.988496e+05         2.989000e+08
# 11  0.000000e+00  1.392811e+07  1.720750e+06         1.020800e+09
# 12  1.363419e+05  1.227077e+05           NaN         0.000000e+00
# 13  1.226925e+05  1.226925e+05           NaN         5.100000e+05
# 14  7.328488e+05  3.004680e+05           NaN         4.340000e+06
# 15  2.414154e+06  9.898033e+05           NaN         1.302000e+07
# 16  8.584800e+05  7.726320e+05           NaN         6.300000e+07
# 17  2.638190e+06  2.374371e+06           NaN         1.820000e+08
# 18  6.132000e+06  1.594320e+06           NaN         1.880000e+08
# 19  6.339603e+06  1.648297e+06           NaN         2.444000e+08
# 20  9.198461e+06  2.943507e+06           NaN         2.400000e+08
# 21  1.558379e+08  1.496044e+08           NaN         0.000000e+00
# 22  7.686089e+06  2.075244e+06           NaN         2.163000e+08
# 23  4.544803e+07  1.227097e+07           NaN         8.652000e+08
# 24  2.377460e+07  1.022308e+07           NaN         8.505000e+08
# 25  7.362482e+07  2.429619e+07           NaN         2.328900e+09
# 26  9.596318e+05  9.596318e+05           NaN         9.129000e+07
# 27  1.370905e+06  9.596336e+05           NaN         0.000000e+00
# 28  3.046229e+07  1.218492e+07           NaN         9.234000e+08
# 29  8.783734e+07  2.898632e+07           NaN         3.617300e+09
# 30  3.591588e+06  1.867626e+06           NaN         9.880000e+07
# 31  9.285600e+06  4.828512e+06           NaN         2.014000e+08
# 32  4.696692e+06  2.442280e+06           NaN         1.292000e+08
# 33  4.767070e+06  2.049840e+06           NaN         8.550000e+07
# 34  1.035714e+07  4.453569e+06           NaN         2.356000e+08
# 35  7.085294e+06  2.409000e+06           NaN         4.730000e+08
# 36  1.227110e+05  1.226923e+05           NaN         0.000000e+00
# 37  9.596329e+05  9.596322e+05           NaN         0.000000e+00
#
#     Operational Expenditure       Revenue  Market Value
# 0              6.294006e+08  6.294006e+08  1.800000e+02
# 1              2.600408e+09  2.600408e+09  1.200000e+02
# 2              0.000000e+00 -6.793206e+10  4.586994e+02
# 3              3.751296e+10  3.751296e+10  2.492000e+02
# 4              0.000000e+00  1.040596e+09  4.303967e+02
# 5              1.916454e+10  1.916454e+10  1.620000e+02
# 6              9.351653e+09  9.351653e+09  2.860000e+02
# 7              2.002304e+09  2.002304e+09  2.826000e+02
# 8              0.000000e+00  2.357265e+09  3.551849e+02
# 9              0.000000e+00  2.857408e+09  3.473930e+02
# 10             1.037885e+08  3.050037e+09  3.820315e+02
# 11             2.507061e+08  5.676965e+09  4.075903e+02
# 12             0.000000e+00  3.120677e+05 -2.288862e+00
# 13             1.595002e+06  4.311275e+06 -3.513887e+01
# 14             1.412200e+07 -1.878829e+07  2.563733e+01
# 15             4.652075e+07 -7.238814e+07  2.998489e+01
# 16             1.622527e+06  1.622527e+06 -1.890000e+00
# 17             4.986179e+06  4.986179e+06 -1.890000e+00
# 18             4.464096e+07 -4.964986e+07  8.096846e+00
# 19             4.615231e+07 -7.767119e+07  1.225174e+01
# 20             8.241821e+07  3.467846e+08 -3.770028e+01
# 21             0.000000e+00  2.177887e-01 -1.397477e-09
# 22             4.150488e+07 -1.022195e+09  1.329929e+02
# 23             2.454193e+08 -6.170651e+09  1.357738e+02
# 24             2.044616e+08 -1.288754e+09  5.420715e+01
# 25             4.859238e+08 -7.887170e+09  1.071265e+02
# 26             9.596318e+06  3.181110e+07 -3.314928e+01
# 27             0.000000e+00  8.019843e+07 -5.850035e+01
# 28             2.436983e+08  1.098748e+09 -3.606912e+01
# 29             5.797265e+08  4.786373e+07 -5.449132e-01
# 30             5.229352e+07 -2.426101e+08  6.754955e+01
# 31             1.351983e+08 -5.775057e+08  6.219369e+01
# 32             6.838384e+07 -3.172594e+08  6.754955e+01
# 33             5.739552e+07 -4.811375e+08  1.009294e+02
# 34             1.246999e+08 -1.091210e+09  1.053583e+02
# 35             2.336730e+08 -9.654784e+08  1.362651e+02
# 36             0.000000e+00  3.264776e+07  2.660945e+02
# 37             0.000000e+00  3.017072e+08  3.143988e+02

# %%
# Example of statistics use: curtailed vRES energy ratio
df = df_stat.groupby("carrier")[["Supply", "Curtailment"]].sum()
df = 1 / (1 + df["Supply"] / df["Curtailment"])
df = df[df > 0].round(3).rename("value").to_frame()
df
# Out:
#                  value
# carrier
# solar PV ground  0.010
# solar PV roof    0.000
# wind onshore     0.084

# %% [markdown]
# #### Plot electrical capacity mix

# %%
from pypsa_pl.plot_outputs import plot_installed_capacities

fig, df = plot_installed_capacities(network)

df = append_annual_sum(df)
df
# Out:
#     year              carrier  value
# 0   2023  battery large power   0.15
# 1   2023           biogas CHP   0.28
# 2   2023     biomass wood CHP   0.46
# 3   2023   biomass wood power   0.40
# 4   2023        hard coal CHP   5.15
# 5   2023      hard coal power  15.14
# 6   2023      hydro PSH power   1.79
# 7   2023            hydro ROR   0.60
# 8   2023        lignite power   7.64
# 9   2023      natural gas CHP   3.95
# 10  2023            other CHP   0.55
# 11  2023      solar PV ground   6.38
# 12  2023        solar PV roof  10.67
# 13  2023         wind onshore   9.43
# 0   2023                  SUM  62.59

# %% [markdown]
# #### Plot electricity generation mix

# %%
from pypsa_pl.plot_outputs import plot_annual_generation

fig, df = plot_annual_generation(network)

df = append_annual_sum(df)
df
# Out:
#     year                carrier         value
# 0   2023  battery large charger -1.400000e-01
# 1   2023    battery large power  1.200000e-01
# 2   2023             biogas CHP  1.290000e+00
# 3   2023       biomass wood CHP  3.240000e+00
# 4   2023     biomass wood power  2.940000e+00
# 5   2023  electricity final use -1.481000e+02
# 6   2023       electricity grid -6.230000e+00
# 7   2023          hard coal CHP  1.435000e+01
# 8   2023        hard coal power  3.452000e+01
# 9   2023        hydro PSH power  9.600000e-01
# 10  2023         hydro PSH pump -1.370000e+00
# 11  2023              hydro ROR  2.420000e+00
# 12  2023          lignite power  4.117000e+01
# 13  2023        natural gas CHP  1.564000e+01
# 14  2023              other CHP  2.410000e+00
# 15  2023        solar PV ground  6.640000e+00
# 16  2023          solar PV roof  8.230000e+00
# 17  2023           wind onshore  2.191000e+01
# 0   2023                    SUM -3.552714e-15

# %% [markdown]
# #### Plot fuel consumption and CO2 emissions

# %%
from pypsa_pl.plot_outputs import plot_fuel_consumption

fig, df = plot_fuel_consumption(network)

df = append_annual_sum(df)
df
# Out:
#    year          fuel   value
# 0  2023        biogas    11.3
# 1  2023  biomass wood    78.0
# 2  2023     hard coal   541.9
# 3  2023       lignite   425.9
# 4  2023   natural gas   117.7
# 5  2023    other fuel    25.5
# 0  2023           SUM  1200.3

# %%
from pypsa_pl.plot_outputs import plot_co2_emissions

fig, df = plot_co2_emissions(network)

df = append_annual_sum(df)
df
# Out:
#    year         fuel   value
# 0  2023    hard coal   51.18
# 1  2023      lignite   47.32
# 2  2023  natural gas    6.54
# 3  2023   other fuel    1.91
# 0  2023          SUM  106.95

# %% [markdown]
# #### Plot hourly electricity generation

# %%
from pypsa_pl.plot_outputs import plot_hourly_generation

n_per_subperiod = 7 * 24
subperiods = [
    (subperiod, (i * n_per_subperiod, (i + 1) * n_per_subperiod))
    for i, subperiod in enumerate(["Jan-Mar", "Apr-Jun", "Aug-Sep", "Oct-Dec"])
]

fig, df = plot_hourly_generation(network, subperiods=subperiods, ylim=(-26, 26))

# %%
df
# Out:
# carrier              battery large charger  battery large power  biogas CHP  \
# 2023-03-09 00:00:00                 -0.056                  0.0       0.218
# 2023-03-09 01:00:00                 -0.072                  0.0       0.219
# 2023-03-09 02:00:00                 -0.072                  0.0       0.219
# 2023-03-09 03:00:00                 -0.073                  0.0       0.222
# 2023-03-09 04:00:00                 -0.078                  0.0       0.232
# ...                                    ...                  ...         ...
# 2023-11-01 19:00:00                  0.000                  0.0       0.205
# 2023-11-01 20:00:00                  0.000                  0.0       0.202
# 2023-11-01 21:00:00                  0.000                  0.0       0.195
# 2023-11-01 22:00:00                 -0.063                  0.0       0.181
# 2023-11-01 23:00:00                 -0.112                  0.0       0.170
#
# carrier              biomass wood CHP  biomass wood power  \
# 2023-03-09 00:00:00             0.442                 0.4
# 2023-03-09 01:00:00             0.442                 0.4
# 2023-03-09 02:00:00             0.442                 0.4
# 2023-03-09 03:00:00             0.442                 0.4
# 2023-03-09 04:00:00             0.442                 0.4
# ...                               ...                 ...
# 2023-11-01 19:00:00             0.442                 0.4
# 2023-11-01 20:00:00             0.442                 0.4
# 2023-11-01 21:00:00             0.442                 0.4
# 2023-11-01 22:00:00             0.442                 0.4
# 2023-11-01 23:00:00             0.442                 0.4
#
# carrier              electricity final use  electricity grid  hard coal CHP  \
# 2023-03-09 00:00:00                -16.146            -0.675          2.502
# 2023-03-09 01:00:00                -15.588            -0.652          2.513
# 2023-03-09 02:00:00                -15.385            -0.644          2.513
# 2023-03-09 03:00:00                -15.368            -0.643          2.556
# 2023-03-09 04:00:00                -15.588            -0.653          2.682
# ...                                    ...               ...            ...
# 2023-11-01 19:00:00                -20.812            -0.867          2.344
# 2023-11-01 20:00:00                -20.085            -0.837          2.312
# 2023-11-01 21:00:00                -18.563            -0.773          2.227
# 2023-11-01 22:00:00                -16.737            -0.700          2.047
# 2023-11-01 23:00:00                -15.334            -0.644          1.910
#
# carrier              hard coal power  hydro PSH power  hydro PSH pump  \
# 2023-03-09 00:00:00            3.785              0.0             0.0
# 2023-03-09 01:00:00            3.785              0.0             0.0
# 2023-03-09 02:00:00            3.785              0.0             0.0
# 2023-03-09 03:00:00            3.785              0.0             0.0
# 2023-03-09 04:00:00            3.785              0.0             0.0
# ...                              ...              ...             ...
# 2023-11-01 19:00:00            3.785              0.0             0.0
# 2023-11-01 20:00:00            3.785              0.0             0.0
# 2023-11-01 21:00:00            3.785              0.0             0.0
# 2023-11-01 22:00:00            3.785              0.0             0.0
# 2023-11-01 23:00:00            3.785              0.0             0.0
#
# carrier              hydro ROR  lignite power  natural gas CHP  other CHP  \
# 2023-03-09 00:00:00      0.276          3.101            2.403      0.275
# 2023-03-09 01:00:00      0.276          2.632            2.411      0.275
# 2023-03-09 02:00:00      0.276          2.525            2.411      0.275
# 2023-03-09 03:00:00      0.276          2.555            2.441      0.275
# 2023-03-09 04:00:00      0.276          2.496            2.531      0.275
# ...                        ...            ...              ...        ...
# 2023-11-01 19:00:00      0.276          7.071            2.290      0.275
# 2023-11-01 20:00:00      0.276          6.191            2.267      0.275
# 2023-11-01 21:00:00      0.276          4.674            2.207      0.275
# 2023-11-01 22:00:00      0.276          3.132            2.078      0.275
# 2023-11-01 23:00:00      0.276          1.977            1.980      0.275
#
# carrier              solar PV ground  solar PV roof  wind onshore
# 2023-03-09 00:00:00              0.0            0.0         3.474
# 2023-03-09 01:00:00              0.0            0.0         3.360
# 2023-03-09 02:00:00              0.0            0.0         3.256
# 2023-03-09 03:00:00              0.0            0.0         3.132
# 2023-03-09 04:00:00              0.0            0.0         3.199
# ...                              ...            ...           ...
# 2023-11-01 19:00:00              0.0            0.0         4.592
# 2023-11-01 20:00:00              0.0            0.0         4.771
# 2023-11-01 21:00:00              0.0            0.0         4.856
# 2023-11-01 22:00:00              0.0            0.0         4.884
# 2023-11-01 23:00:00              0.0            0.0         4.875
#
# [672 rows x 18 columns]

# %% [markdown]
# #### Plot marginal cost of electricity production

# %%
from pypsa_pl.plot_outputs import plot_prices

n_per_subperiod = 7 * 24
subperiods = [
    (subperiod, (i * n_per_subperiod, (i + 1) * n_per_subperiod))
    for i, subperiod in enumerate(["Jan-Mar", "Apr-Jun", "Aug-Sep", "Oct-Dec"])
]

fig, df = plot_prices(network, subperiods=subperiods, ylim=(0, 850))

df_price = df.copy()

# %%
from pypsa_pl.plot_outputs import plot_average_unit_cost_and_price

fig, df = plot_average_unit_cost_and_price(network)

# TGE-DA 2023 mean: 530 PLN/MWh

# Calculate simple (i.e. non-weighted) avg. market price
mean_price = df_price.mean().values[0].round(1)
print("Avg. electricity price (simple):", mean_price, "PLN/MWh")

df
# Out:
# Avg. electricity price (simple): 430.4 PLN/MWh
#            metric  value
# 0  Avg. unit cost  592.7
# 1      Avg. price  458.7

# %% [markdown]
# #### Plot operational costs

# %%
from pypsa_pl.plot_outputs import plot_opex

fig, df = plot_opex(network)

# The sum of OPEX is the objective function's value
df = append_annual_sum(df)

df
# Out:
#     year              aggregation  value
# 1   2023               biogas CHP   0.06
# 2   2023        biogas production   0.01
# 3   2023  biogas substrate supply   0.63
# 4   2023              biomass CHP   0.09
# 5   2023            biomass power   0.08
# 6   2023           biomass supply   2.60
# 7   2023            hard coal CHP   0.29
# 8   2023          hard coal power   0.69
# 9   2023         hard coal supply  37.51
# 10  2023                hydro PSH   0.01
# 11  2023            lignite power   0.82
# 12  2023           lignite supply  19.16
# 13  2023          natural gas CHP   0.44
# 14  2023       natural gas supply   9.35
# 15  2023                other CHP   0.23
# 16  2023        other fuel supply   2.00
# 17  2023             wind onshore   0.35
# 0   2023                      SUM  74.32

# %% [markdown]
# #### Plot revenues net costs

# %%
from pypsa_pl.plot_outputs import plot_net_revenues

fig, df = plot_net_revenues(network, costs=["OPEX"])

df = append_annual_sum(df)

df

# CHP plants have negative net revenues as we do not take into account revenues from heat sales
# Out:
#     year      aggregation  value
# 0   2023    battery large   0.04
# 1   2023       biogas CHP  -0.15
# 4   2023      biomass CHP  -0.22
# 5   2023    biomass power   0.26
# 9   2023    hard coal CHP  -7.48
# 10  2023  hard coal power  -9.87
# 12  2023        hydro PSH   0.40
# 13  2023        hydro ROR   1.04
# 14  2023    lignite power   0.32
# 16  2023  natural gas CHP  -3.15
# 18  2023        other CHP  -1.20
# 20  2023  solar PV ground   2.36
# 21  2023    solar PV roof   2.86
# 22  2023     wind onshore   8.37
# 0   2023              SUM  -6.42

# %% [markdown]
# ### Sensitivity analysis: conventional baseload

# %%
import logging
from matplotlib import pyplot as plt
from io import BytesIO
import ipywidgets as widgets
from ipywidgets import interact_manual

from pypsa_pl.helper_functions import suppress_stdout

# %%
default_p_min_pu = 0.25

def update_p_min_pu_of_public_power_plants(network, p_min_pu=default_p_min_pu):
    is_public_pp = network.links["carrier"].isin(
        ["hard coal power", "lignite power", "biomass wood power"]
    ) & (network.links["qualifier"] == "public")
    if network.meta["reverse_links"]:
        network.links.loc[is_public_pp, "p_max_pu"] = -p_min_pu
    else:
        network.links.loc[is_public_pp, "p_min_pu"] = p_min_pu
    return network

# %%
from pypsa_pl.plot_outputs import plot_curtailed_vres_energy

n_per_subperiod = 7 * 24
subperiods = [
    (subperiod, (i * n_per_subperiod, (i + 1) * n_per_subperiod))
    for i, subperiod in enumerate(["Jan-Mar", "Apr-Jun", "Aug-Sep", "Oct-Dec"])
]

figure_width = 7

def list_plotting_tasks():
    return [
        (
            plot_hourly_generation,
            dict(subperiods=[subperiods[1]], ylim=(-26, 26), figsize=(figure_width, 6)),
        ),
        (
            plot_prices,
            dict(subperiods=[subperiods[1]], ylim=(0, 850), figsize=(figure_width, 4)),
        ),
        (
            plot_annual_generation,
            dict(ylim=(-180, 180), figsize=(figure_width, 6)),
        ),
        (
            plot_curtailed_vres_energy,
            dict(ylim=(0, 5.5), figsize=(figure_width, 4)),
        ),
        (
            plot_co2_emissions,
            dict(ylim=(0, 125), figsize=(figure_width, 5)),
        ),
        (
            plot_opex,
            dict(ylim=(0, 85), figsize=(figure_width, 5)),
        ),
        (
            plot_average_unit_cost_and_price,
            dict(ylim=(0, 850), figsize=(figure_width, 4)),
        ),
        (
            plot_net_revenues,
            dict(ylim=(-46, 46), figsize=(figure_width, 5)),
        ),
    ]

# %%
def make_images(network):
    imgs = []
    for plot_func, kwargs in list_plotting_tasks():
        try:
            fig, _ = plot_func(network, **kwargs)
            img = BytesIO()
            fig.tight_layout()
            px_per_inch = 85
            fig.savefig(img, format="png", dpi=px_per_inch * 2)
            plt.close()
            img.seek(0)
            img = widgets.Image(value=img.read(), format="png")
            width, height = kwargs["figsize"]
            img.layout = widgets.Layout(
                height=f"{px_per_inch*height}px",
                width=f"{px_per_inch*width}px",
                margin="5px 5px 5px 5px",
                border="solid 1.5px darkgrey",
            )
            imgs.append(img)
        except:
            logging.warning(f"Failed to create image with '{plot_func.__name__}'")
    return imgs


def make_widgets(values, images):
    header_layout = widgets.Layout(
        border="solid 1.5px darkgrey",
        margin="5px 5px 5px 5px",
        padding="5px 5px 5px 5px",
    )
    column_layout = widgets.Layout(
        margin="10px 5px 10px 5px",
        padding="5px 5px 5px 5px",
    )
    columns = []
    for key in ["previous", "current"]:
        html = f"""
            <center>
                <div><b>{key.upper()} CALCULATION</b></div>
                <div>p_min_pu: {values[key]['p_min_pu']:.0%}</div>
            </center>"""
        header = widgets.HTML(value=html)
        header.layout = header_layout
        column = widgets.VBox([header] + images[key])
        column.layout = column_layout
        columns.append(column)

    return widgets.HBox(columns)

# %%
values = {"previous": None, "current": {"p_min_pu": default_p_min_pu}}
images = {"previous": None, "current": make_images(network)}


@interact_manual(
    p_min_pu=widgets.FloatSlider(default_p_min_pu, min=0, max=0.301, step=0.01)
)
def recalculate(p_min_pu):

    values["previous"] = values["current"]
    images["previous"] = images["current"]

    update_p_min_pu_of_public_power_plants(network, p_min_pu=p_min_pu)

    with suppress_stdout():
        optimise_network(network, params)

    logging.info("Generating result visualisations...")

    values["current"] = {"p_min_pu": p_min_pu}
    images["current"] = make_images(network)

    return make_widgets(values, images)
# Out:
# interactive(children=(FloatSlider(value=0.25, description='p_min_pu', max=0.301, step=0.01), Button(descriptio…
